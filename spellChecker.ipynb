# %% [markdown]
# <a href="https://colab.research.google.com/github/alwanwrwn/Javanese_Spell_Checker/blob/main/spellChecker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import string
from collections import Counter
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/My Drive/Colab Notebooks/Spell Checker/'

# %%
def read_corpus(corpus):
  with open(corpus, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus(path + 'KamusJawaIndonesia.csv')
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 1977 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 1823 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["dwi"])
# Out:
# 1

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["dwi"])
# Out:
# 0.0005058168942842691

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("dwi"))
# Out:
# [('', 'dwi'), ('d', 'wi'), ('dw', 'i'), ('dwi', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("dwi"))
# Out:
# ['wi', 'di', 'dw']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("bangke"))
# Out:
# ['abngke', 'bnagke', 'bagnke', 'bankge', 'bangek']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("dwi"))
# Out:
# ['awi', 'bwi', 'cwi', 'dwi', 'ewi', 'fwi', 'gwi', 'hwi', 'iwi', 'jwi', 'kwi', 'lwi', 'mwi', 'nwi', 'owi', 'pwi', 'qwi', 'rwi', 'swi', 'twi', 'uwi', 'vwi', 'wwi', 'xwi', 'ywi', 'zwi', 'dai', 'dbi', 'dci', 'ddi', 'dei', 'dfi', 'dgi', 'dhi', 'dii', 'dji', 'dki', 'dli', 'dmi', 'dni', 'doi', 'dpi', 'dqi', 'dri', 'dsi', 'dti', 'dui', 'dvi', 'dwi', 'dxi', 'dyi', 'dzi', 'dwa', 'dwb', 'dwc', 'dwd', 'dwe', 'dwf', 'dwg', 'dwh', 'dwi', 'dwj', 'dwk', 'dwl', 'dwm', 'dwn', 'dwo', 'dwp', 'dwq', 'dwr', 'dws', 'dwt', 'dwu', 'dwv', 'dww', 'dwx', 'dwy', 'dwz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("dwi"))
# Out:
# ['adwi', 'bdwi', 'cdwi', 'ddwi', 'edwi', 'fdwi', 'gdwi', 'hdwi', 'idwi', 'jdwi', 'kdwi', 'ldwi', 'mdwi', 'ndwi', 'odwi', 'pdwi', 'qdwi', 'rdwi', 'sdwi', 'tdwi', 'udwi', 'vdwi', 'wdwi', 'xdwi', 'ydwi', 'zdwi', 'dawi', 'dbwi', 'dcwi', 'ddwi', 'dewi', 'dfwi', 'dgwi', 'dhwi', 'diwi', 'djwi', 'dkwi', 'dlwi', 'dmwi', 'dnwi', 'dowi', 'dpwi', 'dqwi', 'drwi', 'dswi', 'dtwi', 'duwi', 'dvwi', 'dwwi', 'dxwi', 'dywi', 'dzwi', 'dwai', 'dwbi', 'dwci', 'dwdi', 'dwei', 'dwfi', 'dwgi', 'dwhi', 'dwii', 'dwji', 'dwki', 'dwli', 'dwmi', 'dwni', 'dwoi', 'dwpi', 'dwqi', 'dwri', 'dwsi', 'dwti', 'dwui', 'dwvi', 'dwwi', 'dwxi', 'dwyi', 'dwzi', 'dwia', 'dwib', 'dwic', 'dwid', 'dwie', 'dwif', 'dwig', 'dwih', 'dwii', 'dwij', 'dwik', 'dwil', 'dwim', 'dwin', 'dwio', 'dwip', 'dwiq', 'dwir', 'dwis', 'dwit', 'dwiu', 'dwiv', 'dwiw', 'dwix', 'dwiy', 'dwiz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("dwi"))
# Out:
# {'dqi', 'dwih', 'dtwi', 'ldwi', 'dvi', 'dcwi', 'dws', 'dwd', 'dxi', 'dhi', 'mwi', 'dwh', 'dwiy', 'dwwi', 'dwc', 'hwi', 'dgwi', 'drwi', 'dyi', 'kdwi', 'edwi', 'dti', 'dei', 'dwpi', 'vwi', 'dawi', 'zwi', 'dwp', 'dwit', 'dwid', 'dwu', 'dli', 'dwv', 'dwi', 'zdwi', 'uwi', 'adwi', 'dwqi', 'pdwi', 'dwo', 'dwyi', 'owi', 'dwx', 'dwir', 'nwi', 'diw', 'dwib', 'dki', 'dwgi', 'dsi', 'dwie', 'dkwi', 'dw', 'dwzi', 'dwn', 'dwa', 'dfwi', 'dwiz', 'dwy', 'dwik', 'pwi', 'dzwi', 'dwq', 'gdwi', 'djwi', 'fdwi', 'vdwi', 'dwli', 'dwiu', 'dwl', 'dwz', 'dwis', 'iwi', 'xdwi', 'dci', 'dwij', 'diwi', 'twi', 'dwoi', 'rdwi', 'duwi', 'cdwi', 'idwi', 'dewi', 'dwf', 'dwig', 'dwr', 'dfi', 'lwi', 'dmi', 'tdwi', 'kwi', 'hdwi', 'dswi', 'dwci', 'dwio', 'cwi', 'di', 'dai', 'jwi', 'dqwi', 'rwi', 'sdwi', 'dwji', 'mdwi', 'dwic', 'dwg', 'dwmi', 'dwsi', 'awi', 'xwi', 'bdwi', 'dmwi', 'ydwi', 'dwj', 'dwki', 'dvwi', 'dwt', 'udwi', 'dywi', 'dwip', 'wwi', 'dwvi', 'ddwi', 'odwi', 'dui', 'dbi', 'dpi', 'dww', 'dwiq', 'dni', 'dwiw', 'dwb', 'wdwi', 'dwni', 'dwif', 'ndwi', 'ddi', 'dwii', 'dwri', 'dwin', 'ewi', 'dbwi', 'qwi', 'dwdi', 'dwbi', 'dowi', 'dwxi', 'dwiv', 'dii', 'dwim', 'dwhi', 'dwei', 'dji', 'wdi', 'dwil', 'dwti', 'dwai', 'bwi', 'dlwi', 'swi', 'dwk', 'jdwi', 'dnwi', 'dxwi', 'qdwi', 'dri', 'dwia', 'fwi', 'dwix', 'ywi', 'dzi', 'dwui', 'dgi', 'dpwi', 'dwfi', 'wi', 'dhwi', 'gwi', 'dwe', 'doi', 'dwm'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("dwi"))
# Out:
# {'drwki', 'sdtwi', 'hmi', 'dkzwi', 'pwq', 'djwx', 'fwsi', 'dwhg', 'wdt', 'hdww', 'dhwbi', 'kwui', 'dwtw', 'dqwig', 'iudwi', 'dviy', 'swr', 'vdfi', 'bji', 'dckwi', 'dwibd', 'dfxwi', 'dwayi', 'gdzwi', 'thwi', 'vdnwi', 'udci', 'iti', 'dhiy', 'deci', 'udsi', 'qwj', 'pdwf', 'dwsai', 'dewiq', 'ldwbi', 'dwria', 'dwvdi', 'rdjwi', 'bdwd', 'uwci', 'dbit', 'dzuwi', 'ewig', 'dwfif', 'dswzi', 'dibw', 'dwymi', 'xri', 'uwoi', 'dwibu', 'rdwyi', 'dgif', 'dxwai', 'dqwgi', 'cwic', 'ldxi', 'dawiu', 'sww', 'dmj', 'odwui', 'dmo', 'dwsie', 'dnwbi', 'dsi', 'rvdwi', 'dbil', 'hdxi', 'kwir', 'dvh', 'gti', 'mewi', 'idwib', 'twx', 'dwgio', 'dngwi', 'gjdwi', 'dwium', 'dsei', 'dwild', 'doe', 'bwit', 'kdwis', 'ldai', 'dwun', 'pgdwi', 'ddt', 'dwvwi', 'dwyk', 'bdwci', 'iwi', 'djti', 'zwvi', 'tdwti', 'dowfi', 'dtti', 'dlfwi', 'idxi', 'zidwi', 'esdwi', 'dwiob', 'bwy', 'yawi', 'dwbk', 'dsxwi', 'aldwi', 'wkdwi', 'edwt', 'udwid', 'tlwi', 'dnig', 'fdwid', 'dwaxi', 'xci', 'dswiv', 'dwwyi', 'dwbci', 'dwme', 'dwtpi', 'qdwn', 'ywp', 'dwqit', 'dwsc', 'gdui', 'mdwi', 'uhdwi', 'jcdwi', 'fdwix', 'hdqwi', 'idwim', 'gdwiw', 'pldwi', 'dwxbi', 'dwibs', 'djai', 'dwilv', 'rdwvi', 'dwjj', 'dwyxi', 'dewg', 'lwvi', 'fci', 'whdi', 'dhwo', 'duwb', 'wdws', 'dwwiq', 'nbwi', 'dgiu', 'kdwui', 'hdjwi', 'dmgi', 'wdwri', 'ddx', 'kwpi', 'didw', 'dbwiv', 'zdti', 'hdtwi', 'dwdxi', 'tdwiu', 'dkni', 'dqim', 'dwtq', 'idzi', 'wdo', 'dwriv', 'aduwi', 'wdib', 'vmdwi', 'dwiag', 'edwni', 'dcki', 'mwit', 'dcih', 'dwil', 'hduwi', 'ddis', 'dwiop', 'aei', 'dfki', 'dwihl', 'dwiod', 'skwi', 'sdwpi', 'vwni', 'zsi', 'lws', 'dhs', 'cdoi', 'dwfip', 'dwxz', 'pkdwi', 'mwyi', 'dqwvi', 'rwji', 'dwpir', 'dmwr', 'mdwz', 'redwi', 'iwx', 'xdwij', 'dwkim', 'dpd', 'drti', 'dmwqi', 'dpwki', 'dnhwi', 'gfi', 'dwfi', 'dewwi', 'cduwi', 'duhwi', 'wws', 'bdwj', 'dbg', 'qwhi', 'dlowi', 'dvui', 'vdiwi', 'dwjin', 'dwkd', 'dlwiv', 'dgwih', 'zwiu', 'udfwi', 'adwih', 'dauwi', 'dwicj', 'cdwr', 'euwi', 'dxvwi', 'dzhwi', 'odoi', 'dyq', 'div', 'dlt', 'dwirt', 'dnih', 'kdwzi', 'dlwyi', 'dyw', 'ibdwi', 'dnfi', 'dkwqi', 'dsbi', 'qdwe', 'dwexi', 'ybwi', 'hdwo', 'cwx', 'xdmwi', 'dwux', 'dwtie', 'mwzi', 'dhl', 'cdwis', 'ewp', 'dlwip', 'dwvl', 'sddwi', 'hwiq', 'iwim', 'dwijh', 'udwyi', 'xdwig', 'awig', 'jdwci', 'odwio', 'xdwis', 'fwia', 'wzwi', 'dxwf', 'duq', 'doww', 'nwi', 'idwki', 'bdwx', 'qdewi', 'cti', 'mkwi', 'dwije', 'bwti', 'qwid', 'dmwic', 'xwpi', 'qws', 'sddi', 'xli', 'dwikm', 'djwin', 'dwau', 'dnwai', 'cdgwi', 'drwxi', 'kewi', 'dwgoi', 'dwmh', 'dcwn', 'dowl', 'dwapi', 'dwiso', 'wdwif', 'ldwo', 'ddv', 'drei', 'uwn', 'cxwi', 'wwj', 'dgdwi', 'gdwip', 'dlp', 'gdwy', 'pduwi', 'dlqi', 'dwzr', 'mddwi', 'idtwi', 'dljwi', 'dwwe', 'oidwi', 'dbwpi', 'ddn', 'dwrq', 'nai', 'dxuwi', 'abwi', 'nwr', 'dwcfi', 'dkei', 'pwij', 'uwib', 'kdai', 'dcswi', 'qdswi', 'ndwiw', 'vdwiw', 'vdgi', 'idwbi', 'kwoi', 'dwiuc', 'dfc', 'dwiwx', 'zdwic', 'wdwiz', 'dwic', 'dkewi', 'dfwiw', 'dwihb', 'twiw', 'tdwpi', 'owin', 'dswli', 'mnwi', 'mdwli', 'dwyir', 'ydwii', 'cdjwi', 'dwinm', 'iwki', 'mdwbi', 'dzwd', 'kwiq', 'dgwo', 'dsib', 'dewci', 'mdci', 'dcwsi', 'cdwzi', 'xodwi', 'dofi', 'sdwzi', 'wy', 'dwigb', 'dcjwi', 'dwsw', 'dewd', 'dwuu', 'das', 'dqwh', 'dweim', 'dwski', 'dovi', 'gdhwi', 'dta', 'fsi', 'yrdwi', 'qwvi', 'mwsi', 'pdrwi', 'idwif', 'dyhwi', 'aui', 'dwjw', 'dwaq', 'zwio', 'dwqbi', 'dmwhi', 'vdvi', 'dwjwi', 'kwiv', 'hbwi', 'dywit', 'drqi', 'tki', 'dfr', 'gpdwi', 'dnwri', 'dwiwb', 'vwx', 'cw', 'jdwui', 'dfwih', 'kdwki', 'dowp', 'owu', 'sdwsi', 'qdwbi', 'dlih', 'mdww', 'dwpiz', 'dqk', 'dain', 'vlwi', 'odwl', 'ohdwi', 'dgiv', 'cwio', 'zdwia', 'qdwie', 'zdwib', 'diuwi', 'uwio', 'gdwia', 'dmwzi', 'dwhhi', 'odqwi', 'xdcwi', 'xdjwi', 'edtwi', 'drsi', 'dbawi', 'lwc', 'dwrid', 'uwgi', 'dwko', 'lbi', 'gowi', 'dwhix', 'dwns', 'dwgiq', 'hwpi', 'dwjei', 'lwq', 'dwihx', 'dawip', 'dtwti', 'ddwc', 'kwiw', 'dxdi', 'bwiy', 'wzdi', 'xdwil', 'dtiz', 'dwjib', 'dkn', 'udwiy', 'jwv', 'dfwf', 'vdwci', 'ewm', 'dewis', 'ywai', 'gzwi', 'ydwei', 'pdki', 'ewwi', 'dwuci', 'ghdwi', 'udwiw', 'ow ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "kowe"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{word} -> mungkin maksud anda {correct} ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-525f40115614> in <module>()
#       1 word = "kowe"
# ----> 2 corrections = correct_spelling(word, vocabs, word_probas)
#       3
#       4 if corrections:
#       5   print(corrections)
#
# NameError: name 'correct_spelling' is not defined

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker(path + 'KamusJawaIndonesia.csv')

# %%
checker.check("mengko")
# Out:
# [('engko', 0.0005058168942842691),
#  ('mengo', 0.0005058168942842691),
#  ('mengko', 0.0005058168942842691)]
